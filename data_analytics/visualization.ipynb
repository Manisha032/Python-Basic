# %% [markdown]
# ## VISUALIZATION
# - FIGURE
# - axes
# - plot
# - bar
# - scatter
# - hist
# - bos
# - step
# - subplots

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
y = [21,345,56,12,5,47,1]
x = [32,45,78,23,12,44]
plt.plot(y)
plt.plot(x)
plt.show()

# %%
plt.figure(figsize=(15,4))
plt.pie(y)
plt.show()

# %%
figure, ax = plt.subplots(nrows=1, ncols=2, figsize =(15,2))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Manisha\Documents\Python Basic\data_analytics\visualization.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Manisha/Documents/Python%20Basic/data_analytics/visualization.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> figure, ax = plt.subplots(nrows=1, ncols=2, figsize =(15,2))
#       <a href='vscode-notebook-cell:/c%3A/Users/Manisha/Documents/Python%20Basic/data_analytics/visualization.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> plt.show()
#
# NameError: name 'plt' is not defined

# %%
t = np.arange(-3* np.pi, 3 * np.pi, 0.2)
x= np.sin(t)
y = np.cos(t)
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(10,6))
ax[0].plot(t,x,'r')
ax[1].bar(t,y)
plt.show()

# %%
x= [100,200,300,400,500,600,700,800,900,1000]
y = [23,45,1,34,65,2,2,46,34,56,]
plt.plot(x,y, 'go--',linewidth=2, markersize=10, 
         markerfacecolor='white', markeredgecolor='red',)
plt.show()

# %%
plt.plot(x,y, 'go--',linewidth=2, markersize=10, 
         markerfacecolor='white',)
plt.title("Some graph showing",
          fontdict= {'fontsize':15,'fontweight':'light','color':'green'})
plt.xlabel("X axis ki values")
plt.ylabel("Y axis ki values", fontdict ={'color':'red'})
plt.text(800,60,"This is serious\ntext here")
plt.annotate("Peak value",xy=(500,65), xytext=(600,50),
    arrowprops=dict(facecolor='black', width=1))
plt.show()

# %%
x= np.arange(1,10,0.1)
y= 2*x+5
plt.plot(x,y)
